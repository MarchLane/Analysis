# %%
import os
import pandas as pd

# %%
os.chdir(r'C:\Users\alswo\Downloads')
df_1 = pd.read_csv('서울시민_카드소비_업종코드.csv')
# df_1.to_csv('서울시민_카드소비_업종코드_encoding.csv', encoding = 'cp949')
df_1
# Out:
#    UPJONG_CD(업종코드) CLASS1(대분류)  CLASS2(중분류) CLASS3(소분류)
# 0            ss001       요식/유흥           한식          한식
# 1            ss002       요식/유흥     일식/중식/양식          일식
# 2            ss003       요식/유흥     일식/중식/양식          양식
# 3            ss004       요식/유흥     일식/중식/양식          중식
# 4            ss005       요식/유흥  제과/커피/패스트푸드         제과점
# ..             ...         ...          ...         ...
# 69           ss083   스포츠/문화/레저    스포츠/문화/레저        실외골프
# 70           ss084   스포츠/문화/레저    스포츠/문화/레저          스키
# 71           ss090       교육/학원           학원      입시보습학원
# 72           ss091       교육/학원           학원       외국어학원
# 73           ss092       교육/학원           학원       예체능학원
#
# [74 rows x 4 columns]

# %%
df_2 = pd.read_csv('블록_시간대별소액결제건수.csv')
df_2.to_csv('블록_시간대별소액결제건수_encoding.csv', encoding = 'cp949')
df_2
# Out:
#     UPJONG_CLASS3(서울시민업종코드)  YM(기준년월)  TIME(시간대구간)  BLOCK_CD(고객주소블록코드)  \
# 0                     SS003    202005            5               10000
# 1                     SS036    202005            4               10000
# 2                     SS008    202005            6               10000
# 3                     SS013    202005            4               10000
# 4                     SS018    202005            4               10000
# ..                      ...       ...          ...                 ...
# 200                   SS030    202005            2               10000
# 201                   SS092    202005            4               10000
# 202                   SS046    202005            3               10000
# 203                   SS083    202005            3               10000
# 204                   SS063    202005            2               10000
#
#      AMT_CORR(카드이용금액계)  MICRO_PYM(소액결제건수)
# 0                   71               9999
# ...

# %%
df_3 = pd.read_csv('블록_성별연령대별.csv')
df_3.to_csv('블록_성별연령대별_encoding.csv', encoding = 'cp949')
df_3
# Out:
#     UPJONG_CLASS3(서울시민업종코드)  YM(기준년월)  BLOCK_CD(고객주소블록코드) GEDNER(성별)  \
# 0                     SS068    202005               10000          F
# 1                     SS013    202005               10000          M
# 2                     SS055    202005               10000          M
# 3                     SS040    202005               10000          M
# 4                     SS036    202005               10000          M
# ..                      ...       ...                 ...        ...
# 311                   SS031    202005               10000          F
# 312                   SS002    202005               10000          F
# 313                   SS017    202005               10000          M
# 314                   SS024    202005               10000          F
# 315                   SS058    202005               10000          M
#
#     AGE(연령대별)  AMT_CORR(카드이용금액계)  USECT_CORR(카드이용건수계)
# 0         20대               9999                 9999
# ...

# %%
df_4 = pd.read_csv('집계구_일별소비지역별.csv')
df_4.to_csv('집계구_일별소비지역별_encoding.csv', encoding = 'cp949')
df_4
# Out:
#    SIDO(가맹점주소광역시도) SGG(가맹점주소시군구) UPJONG_CLASS1(업종대분류)  YMD(기준일자)  \
# 0               서울          동대문구                   유통   20200516
# 1               서울            중구                요식/유흥   20200516
# 2               서울           성북구                음/식료품   20200516
# 3               서울           성북구                의류/잡화   20200516
# 4               서울           강북구                   유통   20200516
# 5               대전           NaN                가전/가구   20200516
# 6               경기           하남시                   유통   20200516
# 7               서울           관악구                   유통   20200516
# 8               서울           성북구                요식/유흥   20200516
# 9               서울           종로구                   유통   20200516
# 10              서울           관악구                음/식료품   20200516
# 11              서울           도봉구                   유통   20200516
# 12              서울           성북구                   유통   20200516
# ...

# %%
df_5 = pd.read_csv('집계구_일별시간대별.csv')
df_5.to_csv('집계구_일별시간대별_encoding.csv', encoding = 'cp949')
df_5
# Out:
#    UPJONG_CLASS1(업종대분류)  YMD(기준일자)  TIME(시간대구간)  TOT_REG_CD(고객주소집계구별)  \
# 0                 전자상거래   20200506            5         1114059030102
# 1                    유통   20200506            4         1114059030102
# 2                 전자상거래   20200506            6         1114059030102
# 3                 요식/유흥   20200506            2         1114059030102
# 4                    유통   20200506            5         1114059030102
# 5                 의류/잡화   20200506            4         1114059030102
# 6                   자동차   20200506            3         1114059030102
# 7                   자동차   20200506            4         1114059030102
# 8                 요식/유흥   20200506            3         1114059030102
# 9                 전자상거래   20200506            1         1114059030102
# 10            스포츠/문화/레저   20200506            5         1114059030102
# 11                   의료   20200506            3         1114059030102
# ...
