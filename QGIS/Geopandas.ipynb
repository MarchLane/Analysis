# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\지도_SHAPEFILE_대한민국\상권분석\결과')
df_yongsan = pd.read_csv('용산점_250m_SIG-5181_좌표 포함.csv')
df_yongsan
# Out:
#     Unnamed: 0       id                                           geometry  \
# 0            0  10560.0  POLYGON ((336568.346018207 263418.514182261, 3...
# 1            1  11295.0  POLYGON ((337568.346018207 263668.514182261, 3...
# 2            2  11294.0  POLYGON ((337568.346018207 263918.514182261, 3...
# 3            3  10747.0  POLYGON ((336818.346018207 262668.514182261, 3...
# 4            4  11115.0  POLYGON ((337318.346018207 262668.514182261, 3...
# ..         ...      ...                                                ...
# 61          61  12030.0  POLYGON ((338568.346018207 263918.514182261, 3...
# 62          62  12398.0  POLYGON ((339068.346018207 263918.514182261, 3...
# 63          63  10563.0  POLYGON ((336568.346018207 262668.514182261, 3...
# 64          64  10562.0  POLYGON ((336568.346018207 262918.514182261, 3...
# 65          65  10561.0  POLYGON ((336568.346018207 263168.514182261, 3...
#
#       wsg_left    wsg_top   wsg_right  wsg_bottom
# ...

# %%
df_sinseo = pd.read_csv('신서점_250m_SIG-5181_좌표 포함.csv')
df_sinseo
# Out:
#      Unnamed: 0      fid       id  \
# 0             0   5300.0  22691.0
# 1             1   5302.0  22690.0
# 2             2   5303.0  22689.0
# 3             3   5306.0  22695.0
# 4             4   5308.0  22694.0
# ..          ...      ...      ...
# 356         356  13474.0  26377.0
# 357         357  13476.0  26376.0
# 358         358  13480.0  26382.0
# 359         359  13482.0  26381.0
# 360         360  13484.0  26380.0
#
#                                               geometry    wsg_left    wsg_top  \
# 0    POLYGON ((353068.346018207 266668.514182261, 3...  128.695147  35.885509
# 1    POLYGON ((353068.346018207 266918.514182261, 3...  128.695195  35.887762
# 2    POLYGON ((353068.346018207 267168.514182261, 3...  128.695243  35.890014
# 3    POLYGON ((353068.346018207 265668.514182261, 3...  128.694955  35.876501
# 4    POLYGON ((353068.346018207 265918.514182261, 3...  128.695003  35.878753
# ..                                                 ...         ...        ...
# ...

# %%
df_yongsan.iloc[0, 3]
# Out:
# 128.5119225161011
