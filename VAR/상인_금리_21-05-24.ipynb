# %%
import os
import pandas as pd

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\매출데이터')
df_sales = pd.read_csv('무보까 일별 매출_모든 매장_13-10-02_21-03-31.csv')
df_sales.index = df_sales['Unnamed: 0']
del df_sales['Unnamed: 0']
df_sales
# Out:
#                    신평        서문         성서         석적         황상         평리  \
# Unnamed: 0
# 2013-10-02        NaN       NaN        NaN        NaN        NaN        NaN
# 2013-10-04        NaN       NaN        NaN        NaN        NaN        NaN
# 2013-10-05        NaN       NaN        NaN        NaN        NaN        NaN
# 2013-10-06        NaN       NaN        NaN        NaN        NaN        NaN
# 2013-10-07        NaN       NaN        NaN        NaN        NaN        NaN
# ...               ...       ...        ...        ...        ...        ...
# 2021-03-27  1613500.0  294500.0  2605000.0  2605000.0  1613500.0  1613500.0
# 2021-03-28  1203000.0  274000.0  2878500.0  2878500.0  1203000.0  1203000.0
# 2021-03-29   889500.0  205000.0  1438000.0  1438000.0   889500.0   889500.0
# 2021-03-30  1190500.0  202500.0  1719000.0  1719000.0  1190500.0  1190500.0
# 2021-03-31   356000.0       NaN   373000.0   373000.0   356000.0   356000.0
#
#                   구평         신서        원대         안동        서구        남김천  \
# Unnamed: 0
# 2013-10-02       NaN        NaN   15000.0        NaN       NaN        NaN
# 2013-10-04       NaN        NaN  249000.0        NaN       NaN        NaN
# 2013-10-05       NaN        NaN  359000.0        NaN       NaN        NaN
# 2013-10-06       NaN        NaN  413000.0        NaN       NaN        NaN
# 2013-10-07       NaN        NaN  452000.0        NaN       NaN        NaN
# ...              ...        ...       ...        ...       ...        ...
# 2021-03-27       NaN  1613500.0  177000.0  1165500.0  714500.0  1613500.0
# 2021-03-28       NaN  1203000.0  292000.0   617000.0  971500.0  1203000.0
# 2021-03-29  117300.0   889500.0  379000.0   667000.0  697000.0   889500.0
# 2021-03-30  105000.0  1190500.0  247000.0   257500.0  532000.0  1190500.0
# 2021-03-31       NaN   356000.0   14000.0        NaN       NaN   356000.0
#
#                    옥계         장기         용산       엑스코         상인
# Unnamed: 0
# 2013-10-02        NaN        NaN        NaN       NaN        NaN
# 2013-10-04        NaN        NaN        NaN       NaN        NaN
# 2013-10-05        NaN        NaN        NaN       NaN        NaN
# 2013-10-06        NaN        NaN        NaN       NaN        NaN
# 2013-10-07        NaN        NaN        NaN       NaN        NaN
# ...               ...        ...        ...       ...        ...
# 2021-03-27  2190000.0  1613500.0   848000.0  295000.0  1970500.0
# 2021-03-28  2842000.0  1203000.0  1287500.0  267500.0  2075500.0
# 2021-03-29  1038500.0   889500.0   511500.0  318500.0  1742500.0
# 2021-03-30  1784000.0  1190500.0   571500.0  207500.0  1223500.0
# 2021-03-31   510000.0   356000.0        NaN       NaN   403500.0
#
# [2734 rows x 17 columns]

# %%
df_si = pd.DataFrame(df_sales['상인']).dropna()
df_si = df_si.iloc[2:]
df_si
# Out:
#                    상인
# Unnamed: 0
# 2017-11-27  1203000.0
# 2017-11-28  1275000.0
# 2017-11-29  1304500.0
# 2017-11-30  1394000.0
# 2017-12-01  1238000.0
# ...               ...
# 2021-03-27  1970500.0
# 2021-03-28  2075500.0
# 2021-03-29  1742500.0
# 2021-03-30  1223500.0
# 2021-03-31   403500.0
#
# [1191 rows x 1 columns]

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
df_koint = pd.read_csv('KOSPI_금리_휴일메꿈_2014-2021.csv', encoding = 'cp949')
df_koint.index = df_koint['Unnamed: 0']
del df_koint['Unnamed: 0']
df_koint
# Out:
#               KOSPI    금리
# Unnamed: 0
# 2014-01-02  1967.19  2.78
# 2014-01-03  1946.14  2.78
# 2014-01-04  1946.14  2.78
# 2014-01-05  1946.14  2.78
# 2014-01-06  1953.28  2.77
# ...             ...   ...
# 2021-03-27  3041.01  0.89
# 2021-03-28  3041.01  0.89
# 2021-03-29  3036.04  0.89
# 2021-03-30  3070.00  0.89
# 2021-03-31  3061.42  0.89
#
# [2643 rows x 2 columns]

# %%
df_si['금리'] = df_koint['금리']
df_si['금리-6'] = df_si['금리'].shift(6)
df_si = df_si.dropna()
del df_si['금리']
df_si
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\alswo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    상인  금리-6
# Unnamed: 0
# 2017-12-09  2582500.0  2.01
# 2017-12-10  2932000.0  1.99
# 2017-12-11  1174500.0  1.98
# 2017-12-12  1637000.0  1.99
# 2017-12-13  1611000.0  1.98
# ...               ...   ...
# 2021-03-27  1970500.0  0.89
# 2021-03-28  2075500.0  0.89
# 2021-03-29  1742500.0  0.89
# 2021-03-30  1223500.0  0.89
# 2021-03-31   403500.0  0.89
#
# [1179 rows x 2 columns]

# %%
df_si_log = np.log(df_si)
df_si_log
# Out:
#                    상인      금리-6
# Unnamed: 0
# 2017-12-09  14.764268  0.698135
# 2017-12-10  14.891195  0.688135
# 2017-12-11  13.976353  0.683097
# 2017-12-12  14.308376  0.688135
# 2017-12-13  14.292366  0.683097
# ...               ...       ...
# 2021-03-27  14.493798 -0.116534
# 2021-03-28  14.545713 -0.116534
# 2021-03-29  14.370831 -0.116534
# 2021-03-30  14.017226 -0.116534
# 2021-03-31  12.907932 -0.116534
#
# [1179 rows x 2 columns]

# %%
df_si_log['차'] = [a - b for a, b in zip(df_si_log['상인'], df_si_log['금리-6'])]
df_si_log['index'] = [c for c in range(0, len(df_si))]
df_si_log
# Out:
#                    상인      금리-6          차  index
# Unnamed: 0
# 2017-12-09  14.764268  0.698135  14.066134      0
# 2017-12-10  14.891195  0.688135  14.203061      1
# 2017-12-11  13.976353  0.683097  13.293256      2
# 2017-12-12  14.308376  0.688135  13.620241      3
# 2017-12-13  14.292366  0.683097  13.609269      4
# ...               ...       ...        ...    ...
# 2021-03-27  14.493798 -0.116534  14.610332   1174
# 2021-03-28  14.545713 -0.116534  14.662246   1175
# 2021-03-29  14.370831 -0.116534  14.487365   1176
# 2021-03-30  14.017226 -0.116534  14.133760   1177
# 2021-03-31  12.907932 -0.116534  13.024466   1178
#
# [1179 rows x 4 columns]

# %%
plt.figure(figsize = (18, 12))
plt.plot(df_si_log['index'], df_si_log['금리-6'])
plt.xlabel('geumri')
plt.ylabel('cha')
plt.show()

# plt.figure(figsize=(18,12))
# plt.scatter(df_si['금리-6'],df_si['상인'])
# plt.xlabel('\033[31m \033[43m' + 'geumri' + '\033[0m')
# plt.ylabel('sales')
# plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,12))
plt.scatter(df_si['금리-6'],df_si['상인'])
plt.xlabel('\033[31m \033[43m' + 'geumri' + '\033[0m')
plt.ylabel('sales')
plt.show()
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 27 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\alswo\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 27 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df_si_diff = df_si.diff().dropna()
df_si_diff
# Out:
#                    상인  금리-6
# Unnamed: 0
# 2017-12-10   349500.0 -0.02
# 2017-12-11 -1757500.0 -0.01
# 2017-12-12   462500.0  0.01
# 2017-12-13   -26000.0 -0.01
# 2017-12-14   433500.0 -0.01
# ...               ...   ...
# 2021-03-27   852000.0  0.00
# 2021-03-28   105000.0  0.00
# 2021-03-29  -333000.0  0.00
# 2021-03-30  -519000.0  0.00
# 2021-03-31  -820000.0  0.00
#
# [1178 rows x 2 columns]

# %%
df_si_logdiff = np.log(df_si).diff().dropna()
df_si_logdiff
# Out:
#                   상인      금리-6
# Unnamed: 0
# 2017-12-10  0.126927 -0.010000
# 2017-12-11 -0.914842 -0.005038
# 2017-12-12  0.332023  0.005038
# 2017-12-13 -0.016010 -0.005038
# 2017-12-14  0.238298 -0.005063
# ...              ...       ...
# 2021-03-27  0.566299  0.000000
# 2021-03-28  0.051915  0.000000
# 2021-03-29 -0.174881  0.000000
# 2021-03-30 -0.353605  0.000000
# 2021-03-31 -1.109294  0.000000
#
# [1178 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,12))
plt.scatter(df_si_logdiff['금리-6'],df_si_logdiff['상인'])
plt.xlabel('geumri')
plt.ylabel('sales')
plt.show()

# %%
df_si
# Out:
#                    상인  금리-6
# Unnamed: 0
# 2017-12-09  2582500.0  2.01
# 2017-12-10  2932000.0  1.99
# 2017-12-11  1174500.0  1.98
# 2017-12-12  1637000.0  1.99
# 2017-12-13  1611000.0  1.98
# ...               ...   ...
# 2021-03-27  1970500.0  0.89
# 2021-03-28  2075500.0  0.89
# 2021-03-29  1742500.0  0.89
# 2021-03-30  1223500.0  0.89
# 2021-03-31   403500.0  0.89
#
# [1179 rows x 2 columns]
