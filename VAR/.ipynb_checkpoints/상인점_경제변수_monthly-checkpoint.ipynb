# %%
import numpy as np
import pandas as pd
import os
import statsmodels.api as sm
from statsmodels.tsa.api import VAR

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축')
df_1 = pd.read_excel('sangin_monthly_sales.xlsx')
df_1 = df_1.transpose()
df_1.columns = df_1.iloc[0]
df_1 = df_1.iloc[1:]
df_1.index = df_1['날짜']
del df_1['날짜']
in_list = [str(i)[:10] for i in df_1.index]
df_1.index = in_list
df_1
# Out:
# Unnamed: 0 무보까국밥(상인점)
# 2018-01-01   61898000
# 2018-02-01   49484000
# 2018-03-01   52142000
# 2018-04-01   49005500
# 2018-05-01   48055500
# 2018-06-01   45686000
# 2018-07-01   47015000
# 2018-08-01   56392000
# 2018-09-01   52158500
# 2018-10-01   49573500
# 2018-11-01   53709000
# 2018-12-01   61566000
# 2019-01-01   57038500
# 2019-02-01   54490500
# 2019-03-01   49664000
# 2019-04-01   43742000
# 2019-05-01   49220000
# 2019-06-01   47204500
# 2019-07-01   12643500
# 2019-08-01   47223500
# 2019-09-01   57420500
# 2019-10-01   59286000
# 2019-11-01   61008500
# 2019-12-01   69387000
# 2020-01-01   67066500
# 2020-02-01   44161000
# 2020-03-01   35907000
# 2020-04-01   43411000
# 2020-05-01   47947500
# 2020-06-01   42362500
# 2020-07-01   46436000
# 2020-08-01   50191500
# 2020-09-01   50576500
# 2020-10-01   60584500
# 2020-11-01   51665500
# 2020-12-01   42923500

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
df_CPI = pd.read_csv('소비자물가지수_20111~202103_월단위.csv', encoding = 'cp949')
df_CPI = df_CPI.transpose()
df_CPI.columns = df_CPI.iloc[0]
df_CPI = df_CPI.iloc[1:]
df_CPI.index = df_CPI['날짜']
del df_CPI['날짜']
df_CPI
# Out:
# 0          소비자물가지수
# 날짜
# 2011-01-01     93
# 2011-02-01     94
# 2011-03-01     94
# 2011-04-01     94
# 2011-05-01     94
# ...            ...
# 2020-11-01    106
# 2020-12-01    106
# 2021-01-01    106
# 2021-02-01    107
# 2021-03-01    107
#
# [123 rows x 1 columns]

# %%
df_1['소비자물가지수'] = df_CPI['소비자물가지수']
df_1
# Out:
# Unnamed: 0 무보까국밥(상인점) 소비자물가지수
# 2018-01-01   61898000    103
# 2018-02-01   49484000    104
# 2018-03-01   52142000    104
# 2018-04-01   49005500    104
# 2018-05-01   48055500    104
# 2018-06-01   45686000    104
# 2018-07-01   47015000    104
# 2018-08-01   56392000    105
# 2018-09-01   52158500    106
# 2018-10-01   49573500    105
# 2018-11-01   53709000    105
# 2018-12-01   61566000    104
# 2019-01-01   57038500    104
# 2019-02-01   54490500    105
# 2019-03-01   49664000    104
# 2019-04-01   43742000    105
# 2019-05-01   49220000    105
# 2019-06-01   47204500    105
# 2019-07-01   12643500    105
# 2019-08-01   47223500    105
# 2019-09-01   57420500    105
# 2019-10-01   59286000    105
# 2019-11-01   61008500    105
# 2019-12-01   69387000    105
# 2020-01-01   67066500    106
# 2020-02-01   44161000    106
# 2020-03-01   35907000    106
# 2020-04-01   43411000    105
# 2020-05-01   47947500    105
# 2020-06-01   42362500    105
# 2020-07-01   46436000    105
# ...

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\VAR_전처리')
df_1.to_csv('상인월매출_소비자물가지수.csv', encoding = 'cp949')

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
df_PI = pd.read_csv('숙박_음식점_생산지수_2011~202102_월단위.csv')
df_PI = df_PI.transpose()
df_PI = df_PI.iloc[1:]
df_PI.index = df_PI[0]
del df_PI[0]
df_PI.columns = ['숙박_음식점_생산지수']
df_PI
# Out:
#            숙박_음식점_생산지수
# 0
# 2011-01-01        102
# 2011-02-01         93
# 2011-03-01         98
# 2011-04-01        101
# 2011-05-01        109
# ...                ...
# 2020-10-01         83
# 2020-11-01         81
# 2020-12-01         66
# 2021-01-01         60
# 2021-02-01         65
#
# [122 rows x 1 columns]

# %%
df_1['숙박_음식점_생산지수'] = df_PI['숙박_음식점_생산지수']
df_1
# Out:
# Unnamed: 0 무보까국밥(상인점) 소비자물가지수 숙박_음식점_생산지수
# 2018-01-01   61898000    103          96
# 2018-02-01   49484000    104          89
# 2018-03-01   52142000    104          98
# 2018-04-01   49005500    104          97
# 2018-05-01   48055500    104         101
# 2018-06-01   45686000    104          98
# 2018-07-01   47015000    104         102
# 2018-08-01   56392000    105         102
# 2018-09-01   52158500    106          96
# 2018-10-01   49573500    105          98
# 2018-11-01   53709000    105          97
# 2018-12-01   61566000    104         109
# 2019-01-01   57038500    104          97
# 2019-02-01   54490500    105          87
# 2019-03-01   49664000    104          95
# 2019-04-01   43742000    105          96
# 2019-05-01   49220000    105         101
# 2019-06-01   47204500    105          96
# 2019-07-01   12643500    105          99
# 2019-08-01   47223500    105         102
# 2019-09-01   57420500    105          91
# 2019-10-01   59286000    105          98
# ...

# %%
CPI_list = [int(CPI) for CPI in df_1['소비자물가지수']]
PI_list = [int(PI) for PI in df_1['숙박_음식점_생산지수']]
df_1['소비자물가지수'] = CPI_list
df_1['숙박_음식점_생산지수'] = PI_list
df_1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '소비자물가지수'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-e2912a66d71a> in <module>
# ...

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\VAR_전처리')
df_1.to_csv('상인월매출_CPI_PI.csv', encoding = 'cp949')

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\VAR_전처리')
df_1 = pd.read_csv('상인월매출_CPI_PI.csv', encoding = 'cp949')
df_1.index = df_1['Unnamed: 0']
del df_1['Unnamed: 0']
df_1
# Out:
#             무보까국밥(상인점)  숙박_음식점_생산지수
# Unnamed: 0
# 2018-01-01    61898000           96
# 2018-02-01    49484000           89
# 2018-03-01    52142000           98
# 2018-04-01    49005500           97
# 2018-05-01    48055500          101
# 2018-06-01    45686000           98
# 2018-07-01    47015000          102
# 2018-08-01    56392000          102
# 2018-09-01    52158500           96
# 2018-10-01    49573500           98
# 2018-11-01    53709000           97
# 2018-12-01    61566000          109
# 2019-01-01    57038500           97
# 2019-02-01    54490500           87
# 2019-03-01    49664000           95
# 2019-04-01    43742000           96
# 2019-05-01    49220000          101
# 2019-06-01    47204500           96
# 2019-07-01    12643500           99
# 2019-08-01    47223500          102
# 2019-09-01    57420500           91
# 2019-10-01    59286000           98
# 2019-11-01    61008500           97
# 2019-12-01    69387000          110
# ...

# %%
sales_list = [np.int(sales) for sales in df_1['무보까국밥(상인점)']]
df_1['무보까국밥(상인점)'] = sales_list
df_1
# Out:
#             무보까국밥(상인점)  숙박_음식점_생산지수
# Unnamed: 0
# 2018-01-01    61898000           96
# 2018-02-01    49484000           89
# 2018-03-01    52142000           98
# 2018-04-01    49005500           97
# 2018-05-01    48055500          101
# 2018-06-01    45686000           98
# 2018-07-01    47015000          102
# 2018-08-01    56392000          102
# 2018-09-01    52158500           96
# 2018-10-01    49573500           98
# 2018-11-01    53709000           97
# 2018-12-01    61566000          109
# 2019-01-01    57038500           97
# 2019-02-01    54490500           87
# 2019-03-01    49664000           95
# 2019-04-01    43742000           96
# 2019-05-01    49220000          101
# 2019-06-01    47204500           96
# 2019-07-01    12643500           99
# 2019-08-01    47223500          102
# 2019-09-01    57420500           91
# 2019-10-01    59286000           98
# 2019-11-01    61008500           97
# 2019-12-01    69387000          110
# ...

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\VAR_전처리')
df_1.to_csv('상인월매출_CPI_PI.csv', encoding = 'cp949')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-132-cb10bdb824e2> in <module>
#       1 os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\VAR_전처리')
# ----> 2 df_1.to_csv('상인월매출_CPI_PI.csv', encoding = 'cp949')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3401             doublequote=doublequote,
#    3402             escapechar=escapechar,
# -> 3403             storage_options=storage_options,
#    3404         )
#    3405
#
# ...

# %%
df_1_log = np.log(df_1)
df_1_log
# Out:
# Unnamed: 0  무보까국밥(상인점)   소비자물가지수  숙박_음식점_생산지수
# 2018-01-01   17.940998  4.634729     4.564348
# 2018-02-01   17.717160  4.644391     4.488636
# 2018-03-01   17.769481  4.644391     4.584967
# 2018-04-01   17.707443  4.644391     4.574711
# 2018-05-01   17.687867  4.644391     4.615121
# 2018-06-01   17.637302  4.644391     4.584967
# 2018-07-01   17.665977  4.644391     4.624973
# 2018-08-01   17.847838  4.653960     4.624973
# 2018-09-01   17.769798  4.663439     4.564348
# 2018-10-01   17.718967  4.653960     4.584967
# 2018-11-01   17.799091  4.653960     4.574711
# 2018-12-01   17.935620  4.644391     4.691348
# 2019-01-01   17.859237  4.644391     4.574711
# 2019-02-01   17.813537  4.653960     4.465908
# 2019-03-01   17.720791  4.644391     4.553877
# 2019-04-01   17.593819  4.653960     4.564348
# 2019-05-01   17.711811  4.653960     4.615121
# 2019-06-01   17.670000  4.653960     4.564348
# 2019-07-01   16.352654  4.653960     4.595120
# ...

# %%
df_1_in = df_1.diff().dropna()
df_1_in ## 차분
# Out:
# Unnamed: 0 무보까국밥(상인점)  소비자물가지수  숙박_음식점_생산지수
# 2018-02-01  -12414000      1.0         -7.0
# 2018-03-01    2658000      0.0          9.0
# 2018-04-01   -3136500      0.0         -1.0
# 2018-05-01    -950000      0.0          4.0
# 2018-06-01   -2369500      0.0         -3.0
# 2018-07-01    1329000      0.0          4.0
# 2018-08-01    9377000      1.0          0.0
# 2018-09-01   -4233500      1.0         -6.0
# 2018-10-01   -2585000     -1.0          2.0
# 2018-11-01    4135500      0.0         -1.0
# 2018-12-01    7857000     -1.0         12.0
# 2019-01-01   -4527500      0.0        -12.0
# 2019-02-01   -2548000      1.0        -10.0
# 2019-03-01   -4826500     -1.0          8.0
# 2019-04-01   -5922000      1.0          1.0
# 2019-05-01    5478000      0.0          5.0
# 2019-06-01   -2015500      0.0         -5.0
# 2019-07-01  -34561000      0.0          3.0
# 2019-08-01   34580000      0.0          3.0
# 2019-09-01   10197000      0.0        -11.0
# ...

# %%
df_1_logdiff = np.log(df_1).diff().dropna()
df_1_logdiff  ##분산차분
# Out:
# Unnamed: 0  무보까국밥(상인점)   소비자물가지수  숙박_음식점_생산지수
# 2018-02-01   -0.223838  0.009662    -0.075712
# 2018-03-01    0.052321  0.000000     0.096331
# 2018-04-01   -0.062038  0.000000    -0.010257
# 2018-05-01   -0.019576  0.000000     0.040410
# 2018-06-01   -0.050565  0.000000    -0.030153
# 2018-07-01    0.028675  0.000000     0.040005
# 2018-08-01    0.181861  0.009569     0.000000
# 2018-09-01   -0.078040  0.009479    -0.060625
# 2018-10-01   -0.050831 -0.009479     0.020619
# 2018-11-01    0.080124  0.000000    -0.010257
# 2018-12-01    0.136529 -0.009569     0.116637
# 2019-01-01   -0.076383  0.000000    -0.116637
# 2019-02-01   -0.045700  0.009569    -0.108803
# 2019-03-01   -0.092746 -0.009569     0.087969
# 2019-04-01   -0.126972  0.009569     0.010471
# 2019-05-01    0.117991  0.000000     0.050772
# 2019-06-01   -0.041811  0.000000    -0.050772
# 2019-07-01   -1.317346  0.000000     0.030772
# 2019-08-01    1.317748  0.000000     0.029853
# ...

# %%
model = VAR(df_1_log)
results = model.fit(7)
results.summary()
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 05, May, 2021
# Time:                     15:22:16
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -14.5833
# Nobs:                     29.0000    HQIC:                  -16.7205
# Log likelihood:           199.130    FPE:                8.42894e-08
# AIC:                     -17.6950    Det(Omega_mle):     1.54973e-08
# --------------------------------------------------------------------
# Results for equation 무보까국밥(상인점)
# ...
#                     coefficient       std. error           t-stat            prob
# ...

# %% [markdown]
# #### EPU

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
EPU = pd.read_excel('Korea_Policy_Uncertainty_Data.xlsx')
EPU.index = EPU['Date']
del EPU['Date']
EPU
# Out:
#                      New South Korean EPU Index
# Date
# 1/1990                               129.638657
# 2/1990                                73.562210
# 3/1990                               102.012573
# 4/1990                               118.501373
# 5/1990                                45.044033
# ...                                         ...
# 2020-09-01 00:00:00                  136.296806
# 2020-10-01 00:00:00                  189.379096
# 2020-11-01 00:00:00                  287.691066
# 2020-12-01 00:00:00                  182.512180
# 1/2021                               212.168949
#
# [373 rows x 1 columns]

# %%
EPU_in_list = [str(EPU_in)[:10] for EPU_in in EPU.index]
EPU.index = EPU_in_list
EPU
# Out:
#             New South Korean EPU Index
# 1/1990                      129.638657
# 2/1990                       73.562210
# 3/1990                      102.012573
# 4/1990                      118.501373
# 5/1990                       45.044033
# ...                                ...
# 2020-09-01                  136.296806
# 2020-10-01                  189.379096
# 2020-11-01                  287.691066
# 2020-12-01                  182.512180
# 1/2021                      212.168949
#
# [373 rows x 1 columns]

# %%
df_1['KOR_EPU'] = EPU['New South Korean EPU Index']
df_1
# Out:
#             무보까국밥(상인점)     KOR_EPU
# Unnamed: 0
# 2018-01-01    61898000   95.630259
# 2018-02-01    49484000   71.157354
# 2018-03-01    52142000  129.418991
# 2018-04-01    49005500  103.855925
# 2018-05-01    48055500  134.964252
# 2018-06-01    45686000  126.329389
# 2018-07-01    47015000  155.153873
# 2018-08-01    56392000  149.484414
# 2018-09-01    52158500  153.960057
# 2018-10-01    49573500  176.211079
# 2018-11-01    53709000  203.245371
# 2018-12-01    61566000  243.033558
# 2019-01-01    57038500  249.436502
# 2019-02-01    54490500  146.823761
# 2019-03-01    49664000  172.994763
# 2019-04-01    43742000  138.911178
# 2019-05-01    49220000  230.145752
# 2019-06-01    47204500  248.528870
# 2019-07-01    12643500  316.855461
# 2019-08-01    47223500  538.176765
# 2019-09-01    57420500  275.198547
# 2019-10-01    59286000  274.024402
# 2019-11-01    61008500  239.355950
# 2019-12-01    69387000  257.886125
# 2020-01-01    67066500  255.230495
# ...

# %%
del df_1['소비자물가지수'], df_1['숙박_음식점_생산지수']
df_1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '소비자물가지수'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-d2536ece55cb> in <module>
# ...

# %%
df_1
# Out:
#     무보까국밥(상인점)  숙박_음식점_생산지수
# 0     61898000           96
# 1     49484000           89
# 2     52142000           98
# 3     49005500           97
# 4     48055500          101
# 5     45686000           98
# 6     47015000          102
# 7     56392000          102
# 8     52158500           96
# 9     49573500           98
# 10    53709000           97
# 11    61566000          109
# 12    57038500           97
# 13    54490500           87
# 14    49664000           95
# 15    43742000           96
# 16    49220000          101
# 17    47204500           96
# 18    12643500           99
# 19    47223500          102
# 20    57420500           91
# 21    59286000           98
# 22    61008500           97
# 23    69387000          110
# 24    67066500           95
# 25    44161000           74
# 26    35907000           64
# 27    43411000           72
# 28    47947500           87
# 29    42362500           85
# 30    46436000           90
# 31    50191500           85
# ...

# %%
df_1_logdiff = np.log(df_1).diff().dropna()
df_1_logdiff
# Out:
#     무보까국밥(상인점)  숙박_음식점_생산지수
# 1    -0.223838    -0.075712
# 2     0.052321     0.096331
# 3    -0.062038    -0.010257
# 4    -0.019576     0.040410
# 5    -0.050565    -0.030153
# 6     0.028675     0.040005
# 7     0.181861     0.000000
# 8    -0.078040    -0.060625
# 9    -0.050831     0.020619
# 10    0.080124    -0.010257
# 11    0.136529     0.116637
# 12   -0.076383    -0.116637
# 13   -0.045700    -0.108803
# 14   -0.092746     0.087969
# 15   -0.126972     0.010471
# 16    0.117991     0.050772
# 17   -0.041811    -0.050772
# 18   -1.317346     0.030772
# 19    1.317748     0.029853
# 20    0.195510    -0.114113
# 21    0.031972     0.074108
# 22    0.028640    -0.010257
# 23    0.128686     0.125769
# 24   -0.034015    -0.146603
# 25   -0.417843    -0.249812
# 26   -0.206910    -0.145182
# 27    0.189781     0.117783
# 28    0.099394     0.189242
# 29   -0.123843    -0.023257
# 30    0.091811     0.057158
# 31    0.077771    -0.057158
# 32    0.007641    -0.165985
# ...

# %%
model = VAR(df_1_logdiff)
results = model.fit(8)
results.summary()
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 05, May, 2021
# Time:                     15:55:40
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -5.07405
# Nobs:                     27.0000    HQIC:                  -6.22063
# Log likelihood:           47.9063    FPE:                 0.00190903
# AIC:                     -6.70585    Det(Omega_mle):     0.000718846
# --------------------------------------------------------------------
# Results for equation 무보까국밥(상인점)
# ...
#                     coefficient       std. error           t-stat            prob
# ...

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\VAR_전처리')
df_1 = pd.read_csv('상인월매출_CPI_PI.csv', encoding = 'cp949')
del df_1['소비자물가지수']
del df_1['Unnamed: 0']
df_1
# Out:
#     무보까국밥(상인점)  숙박_음식점_생산지수
# 0     61898000           96
# 1     49484000           89
# 2     52142000           98
# 3     49005500           97
# 4     48055500          101
# 5     45686000           98
# 6     47015000          102
# 7     56392000          102
# 8     52158500           96
# 9     49573500           98
# 10    53709000           97
# 11    61566000          109
# 12    57038500           97
# 13    54490500           87
# 14    49664000           95
# 15    43742000           96
# 16    49220000          101
# 17    47204500           96
# 18    12643500           99
# 19    47223500          102
# 20    57420500           91
# 21    59286000           98
# 22    61008500           97
# 23    69387000          110
# 24    67066500           95
# 25    44161000           74
# 26    35907000           64
# 27    43411000           72
# 28    47947500           87
# 29    42362500           85
# 30    46436000           90
# 31    50191500           85
# ...

# %%
df_1_logdiff = np.log(df_1).diff().dropna()
df_1_logdiff

model = VAR(df_1_logdiff)
results = model.fit(8)
results.summary()
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 05, May, 2021
# Time:                     15:54:48
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -5.07405
# Nobs:                     27.0000    HQIC:                  -6.22063
# Log likelihood:           47.9063    FPE:                 0.00190903
# AIC:                     -6.70585    Det(Omega_mle):     0.000718846
# --------------------------------------------------------------------
# Results for equation 무보까국밥(상인점)
# ...
#                     coefficient       std. error           t-stat            prob
# ...

# %%
del df_1['숙박_음식점_생산지수']
df_1
# Out:
#             무보까국밥(상인점)
# Unnamed: 0
# 2018-01-01    61898000
# 2018-02-01    49484000
# 2018-03-01    52142000
# 2018-04-01    49005500
# 2018-05-01    48055500
# 2018-06-01    45686000
# 2018-07-01    47015000
# 2018-08-01    56392000
# 2018-09-01    52158500
# 2018-10-01    49573500
# 2018-11-01    53709000
# 2018-12-01    61566000
# 2019-01-01    57038500
# 2019-02-01    54490500
# 2019-03-01    49664000
# 2019-04-01    43742000
# 2019-05-01    49220000
# 2019-06-01    47204500
# 2019-07-01    12643500
# 2019-08-01    47223500
# 2019-09-01    57420500
# 2019-10-01    59286000
# 2019-11-01    61008500
# 2019-12-01    69387000
# 2020-01-01    67066500
# 2020-02-01    44161000
# 2020-03-01    35907000
# 2020-04-01    43411000
# 2020-05-01    47947500
# 2020-06-01    42362500
# 2020-07-01    46436000
# 2020-08-01    50191500
# 2020-09-01    50576500
# 2020-10-01    60584500
# 2020-11-01    51665500
# 2020-12-01    42923500

# %%
df_1_logdiff = np.log(df_1).diff().dropna()
df_1_logdiff

model = VAR(df_1_logdiff)
results = model.fit(8)
results.summary()
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 05, May, 2021
# Time:                     17:23:36
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -3.31770
# Nobs:                     27.0000    HQIC:                  -4.46428
# Log likelihood:           24.1955    FPE:                  0.0110558
# AIC:                     -4.94949    Det(Omega_mle):      0.00416304
# --------------------------------------------------------------------
# Results for equation 무보까국밥(상인점)
# ...
#                    coefficient       std. error           t-stat            prob
# ...

# %%
df_1.to_csv('상인월매출_EPU.csv', encoding = 'cp949')

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
ppi = pd.read_csv('생산자물가지수_2011~202103_월단위.csv', encoding = 'cp949')
ppi = ppi.transpose()
ppi.columns = ppi.iloc[0]
ppi = ppi.iloc[1:]
ppi.index = ppi['연월']
del ppi['연월']
ppi
# Out:
# Unnamed: 0 생산자물가지수
# 연월
# 2011-01-01     103
# 2011-02-01     104
# 2011-03-01     105
# 2011-04-01     106
# 2011-05-01     106
# ...            ...
# 2020-11-01     103
# 2020-12-01     104
# 2021-01-01     105
# 2021-02-01     106
# 2021-03-01     107
#
# [123 rows x 1 columns]

# %%
df_1['생산자물가지수'] = ppi['생산자물가지수']
#del df_1['KOR_EPU']
df_1
# Out:
#             무보까국밥(상인점) 생산자물가지수
# Unnamed: 0
# 2018-01-01    61898000     103
# 2018-02-01    49484000     103
# 2018-03-01    52142000     103
# 2018-04-01    49005500     103
# 2018-05-01    48055500     103
# 2018-06-01    45686000     103
# 2018-07-01    47015000     104
# 2018-08-01    56392000     104
# 2018-09-01    52158500     105
# 2018-10-01    49573500     104
# 2018-11-01    53709000     104
# 2018-12-01    61566000     103
# 2019-01-01    57038500     103
# 2019-02-01    54490500     103
# 2019-03-01    49664000     103
# 2019-04-01    43742000     104
# 2019-05-01    49220000     104
# 2019-06-01    47204500     104
# 2019-07-01    12643500     104
# 2019-08-01    47223500     104
# 2019-09-01    57420500     104
# 2019-10-01    59286000     104
# 2019-11-01    61008500     103
# 2019-12-01    69387000     104
# 2020-01-01    67066500     104
# 2020-02-01    44161000     104
# 2020-03-01    35907000     103
# 2020-04-01    43411000     102
# ...

# %%
ppi_list = [int(ppi) for ppi in df_1['생산자물가지수']]
df_1['생산자물가지수'] = ppi_list
df_1
# Out:
#             무보까국밥(상인점)  생산자물가지수
# Unnamed: 0
# 2018-01-01    61898000      103
# 2018-02-01    49484000      103
# 2018-03-01    52142000      103
# 2018-04-01    49005500      103
# 2018-05-01    48055500      103
# 2018-06-01    45686000      103
# 2018-07-01    47015000      104
# 2018-08-01    56392000      104
# 2018-09-01    52158500      105
# 2018-10-01    49573500      104
# 2018-11-01    53709000      104
# 2018-12-01    61566000      103
# 2019-01-01    57038500      103
# 2019-02-01    54490500      103
# 2019-03-01    49664000      103
# 2019-04-01    43742000      104
# 2019-05-01    49220000      104
# 2019-06-01    47204500      104
# 2019-07-01    12643500      104
# 2019-08-01    47223500      104
# 2019-09-01    57420500      104
# 2019-10-01    59286000      104
# 2019-11-01    61008500      103
# 2019-12-01    69387000      104
# 2020-01-01    67066500      104
# 2020-02-01    44161000      104
# 2020-03-01    35907000      103
# 2020-04-01    43411000      102
# ...

# %%
df_1_logdiff = np.log(df_1).diff().dropna()
df_1_logdiff

model = VAR(df_1_logdiff)
results = model.fit(8)
results.summary()
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 05, May, 2021
# Time:                     18:00:42
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -11.1546
# Nobs:                     27.0000    HQIC:                  -12.3011
# Log likelihood:           129.993    FPE:                4.36594e-06
# AIC:                     -12.7864    Det(Omega_mle):     1.64399e-06
# --------------------------------------------------------------------
# Results for equation 무보까국밥(상인점)
# ...
#                    coefficient       std. error           t-stat            prob
# ...

# %%
df_1.to_csv('상인월매출_PPI.csv', encoding = 'cp949')

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\VAR_전처리')
cpi = pd.read_csv('상인월매출_소비자물가지수.csv', encoding = 'cp949')
cpi.index = cpi['Unnamed: 0']
del cpi['Unnamed: 0']
cpi
# Out:
#             무보까국밥(상인점)  소비자물가지수
# Unnamed: 0
# 2018-01-01    61898000      103
# 2018-02-01    49484000      104
# 2018-03-01    52142000      104
# 2018-04-01    49005500      104
# 2018-05-01    48055500      104
# 2018-06-01    45686000      104
# 2018-07-01    47015000      104
# 2018-08-01    56392000      105
# 2018-09-01    52158500      106
# 2018-10-01    49573500      105
# 2018-11-01    53709000      105
# 2018-12-01    61566000      104
# 2019-01-01    57038500      104
# 2019-02-01    54490500      105
# 2019-03-01    49664000      104
# 2019-04-01    43742000      105
# 2019-05-01    49220000      105
# 2019-06-01    47204500      105
# 2019-07-01    12643500      105
# 2019-08-01    47223500      105
# 2019-09-01    57420500      105
# 2019-10-01    59286000      105
# 2019-11-01    61008500      105
# 2019-12-01    69387000      105
# 2020-01-01    67066500      106
# 2020-02-01    44161000      106
# 2020-03-01    35907000      106
# 2020-04-01    43411000      105
# ...

# %%
df_1_logdiff = np.log(cpi).diff().dropna()
df_1_logdiff

model = VAR(df_1_logdiff)
results = model.fit(8)
results.summary()
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 05, May, 2021
# Time:                     18:17:01
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -11.2982
# Nobs:                     27.0000    HQIC:                  -12.4447
# Log likelihood:           131.932    FPE:                3.78199e-06
# AIC:                     -12.9300    Det(Omega_mle):     1.42411e-06
# --------------------------------------------------------------------
# Results for equation 무보까국밥(상인점)
# ...
#                    coefficient       std. error           t-stat            prob
# ...

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
csi = pd.read_csv('소비자동향지수_2011_202104_월단위.csv', encoding = 'cp949')
csi = csi.transpose()
csi.columns = csi.iloc[0]
csi = csi.iloc[1:]
csi.index = csi['날짜']
del csi['날짜']
csi
# Out:
#            소비자동향지수
# 날짜
# 2011-01-01     106
# 2011-02-01     104
# 2011-03-01     100
# 2011-04-01      99
# 2011-05-01      99
# ...            ...
# 2020-12-01      93
# 2021-01-01      96
# 2021-02-01      96
# 2021-03-01      96
# 2021-04-01      97
#
# [124 rows x 1 columns]

# %%
#del df_1['생산자물가지수']
df_1['소비자동향지수'] = csi['소비자동향지수']
df_1
# Out:
#             무보까국밥(상인점) 소비자동향지수
# Unnamed: 0
# 2018-01-01    61898000     105
# 2018-02-01    49484000     103
# 2018-03-01    52142000     103
# 2018-04-01    49005500     102
# 2018-05-01    48055500     101
# 2018-06-01    45686000     101
# 2018-07-01    47015000      99
# 2018-08-01    56392000      98
# 2018-09-01    52158500     101
# 2018-10-01    49573500      99
# 2018-11-01    53709000      97
# 2018-12-01    61566000      99
# 2019-01-01    57038500      98
# 2019-02-01    54490500      98
# 2019-03-01    49664000      98
# 2019-04-01    43742000      99
# 2019-05-01    49220000      97
# 2019-06-01    47204500      97
# 2019-07-01    12643500      96
# 2019-08-01    47223500      94
# 2019-09-01    57420500      97
# 2019-10-01    59286000      97
# 2019-11-01    61008500      99
# 2019-12-01    69387000      98
# 2020-01-01    67066500     101
# 2020-02-01    44161000      97
# 2020-03-01    35907000      87
# 2020-04-01    43411000      83
# ...

# %%
cpi_list = [int(cpi_each) for cpi_each in df_1['소비자동향지수']]
df_1['소비자동향지수'] = cpi_list
df_1
# Out:
#             무보까국밥(상인점)  소비자동향지수
# Unnamed: 0
# 2018-01-01    61898000      105
# 2018-02-01    49484000      103
# 2018-03-01    52142000      103
# 2018-04-01    49005500      102
# 2018-05-01    48055500      101
# 2018-06-01    45686000      101
# 2018-07-01    47015000       99
# 2018-08-01    56392000       98
# 2018-09-01    52158500      101
# 2018-10-01    49573500       99
# 2018-11-01    53709000       97
# 2018-12-01    61566000       99
# 2019-01-01    57038500       98
# 2019-02-01    54490500       98
# 2019-03-01    49664000       98
# 2019-04-01    43742000       99
# 2019-05-01    49220000       97
# 2019-06-01    47204500       97
# 2019-07-01    12643500       96
# 2019-08-01    47223500       94
# 2019-09-01    57420500       97
# 2019-10-01    59286000       97
# 2019-11-01    61008500       99
# 2019-12-01    69387000       98
# 2020-01-01    67066500      101
# 2020-02-01    44161000       97
# 2020-03-01    35907000       87
# 2020-04-01    43411000       83
# ...

# %%
df_1_logdiff = np.log(df_1).diff().dropna()
df_1_logdiff

model = VAR(df_1_logdiff)
results = model.fit(8)
results.summary()
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 05, May, 2021
# Time:                     18:24:45
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -7.13044
# Nobs:                     27.0000    HQIC:                  -8.27701
# Log likelihood:           75.6675    FPE:                0.000244195
# AIC:                     -8.76223    Det(Omega_mle):     9.19516e-05
# --------------------------------------------------------------------
# Results for equation 무보까국밥(상인점)
# ...
#                    coefficient       std. error           t-stat            prob
# ...

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\VAR_전처리')
df_1.to_csv('상인월매출_소비자동향지수')

# %%
df_1
# Out:
#             무보까국밥(상인점)
# Unnamed: 0
# 2018-01-01    61898000
# 2018-02-01    49484000
# 2018-03-01    52142000
# 2018-04-01    49005500
# 2018-05-01    48055500
# 2018-06-01    45686000
# 2018-07-01    47015000
# 2018-08-01    56392000
# 2018-09-01    52158500
# 2018-10-01    49573500
# 2018-11-01    53709000
# 2018-12-01    61566000
# 2019-01-01    57038500
# 2019-02-01    54490500
# 2019-03-01    49664000
# 2019-04-01    43742000
# 2019-05-01    49220000
# 2019-06-01    47204500
# 2019-07-01    12643500
# 2019-08-01    47223500
# 2019-09-01    57420500
# 2019-10-01    59286000
# 2019-11-01    61008500
# 2019-12-01    69387000
# 2020-01-01    67066500
# 2020-02-01    44161000
# 2020-03-01    35907000
# 2020-04-01    43411000
# 2020-05-01    47947500
# 2020-06-01    42362500
# 2020-07-01    46436000
# 2020-08-01    50191500
# 2020-09-01    50576500
# 2020-10-01    60584500
# 2020-11-01    51665500
# 2020-12-01    42923500

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
esi = pd.read_csv('경제심리지수_2011~202104_월단위.csv', encoding = 'cp949')
esi = esi.transpose()
esi.columns = esi.iloc[0]
esi = esi.iloc[1:]
esi.index = esi['연월']
del esi['연월']
esi
# Out:
#            경제심리지수
# 연월
# 2011-01-01    111
# 2011-02-01    112
# 2011-03-01    109
# 2011-04-01    113
# 2011-05-01    111
# ...           ...
# 2020-12-01     86
# 2021-01-01     93
# 2021-02-01     97
# 2021-03-01    101
# 2021-04-01    105
#
# [124 rows x 1 columns]

# %%
del df_1['경제심리지수']

# %%
#del df_1['소비자동향지수']
df_1['경제심리지수'] = esi['경제심리지수']
esi_list = [int(esi_each) for esi_each in df_1['경제심리지수']]
df_1['경제심리지수'] = esi_list
df_1
# Out:
#             무보까국밥(상인점)  경제심리지수
# Unnamed: 0
# 2018-01-01    61898000     100
# 2018-02-01    49484000     101
# 2018-03-01    52142000      98
# 2018-04-01    49005500     100
# 2018-05-01    48055500     102
# 2018-06-01    45686000     100
# 2018-07-01    47015000      96
# 2018-08-01    56392000      97
# 2018-09-01    52158500      99
# 2018-10-01    49573500      95
# 2018-11-01    53709000      95
# 2018-12-01    61566000      95
# 2019-01-01    57038500      92
# 2019-02-01    54490500      97
# 2019-03-01    49664000      97
# 2019-04-01    43742000      98
# 2019-05-01    49220000      94
# 2019-06-01    47204500      95
# 2019-07-01    12643500      92
# 2019-08-01    47223500      92
# 2019-09-01    57420500      94
# 2019-10-01    59286000      94
# 2019-11-01    61008500      94
# 2019-12-01    69387000      95
# 2020-01-01    67066500      98
# 2020-02-01    44161000      90
# 2020-03-01    35907000      70
# 2020-04-01    43411000      63
# ...

# %%
df_1_logdiff = np.log(df_1).diff().dropna()
df_1_logdiff

model = VAR(df_1_logdiff)
results = model.fit(8)
results.summary()
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 05, May, 2021
# Time:                     18:33:21
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -5.97359
# Nobs:                     27.0000    HQIC:                  -7.12017
# Log likelihood:           60.0501    FPE:                0.000776512
# AIC:                     -7.60539    Det(Omega_mle):     0.000292395
# --------------------------------------------------------------------
# Results for equation 무보까국밥(상인점)
# ...
#                    coefficient       std. error           t-stat            prob
# ...

# %%
df_1.to_csv('상인점월매출.csv', encoding = 'cp949')

# %%
kospi = pd.read_csv('KOSPI_2011~202104_월단위.csv', encoding = 'cp949')
kospi.index = kospi['연월']
del kospi['연월']
kospi
# Out:
#               종가
# 연월
# 2011-01-01  2070
# 2011-02-01  1939
# 2011-03-01  2107
# 2011-04-01  2192
# 2011-05-01  2142
# ...          ...
# 2020-12-01  2873
# 2021-01-01  2976
# 2021-02-01  3013
# 2021-03-01  3061
# 2021-04-01  3148
#
# [124 rows x 1 columns]

# %%
#del df_1['경제심리지수']
df_1['kospi'] = kospi['종가']
kospi_list = [int(kospi_each) for kospi_each in df_1['kospi']]
df_1['kospi'] = kospi_list
df_1
# Out:
#             무보까국밥(상인점)  kospi
# Unnamed: 0
# 2018-01-01    61898000   2566
# 2018-02-01    49484000   2427
# 2018-03-01    52142000   2446
# 2018-04-01    49005500   2515
# 2018-05-01    48055500   2423
# 2018-06-01    45686000   2326
# 2018-07-01    47015000   2295
# 2018-08-01    56392000   2323
# 2018-09-01    52158500   2343
# 2018-10-01    49573500   2030
# 2018-11-01    53709000   2097
# 2018-12-01    61566000   2041
# 2019-01-01    57038500   2205
# 2019-02-01    54490500   2195
# 2019-03-01    49664000   2141
# 2019-04-01    43742000   2204
# 2019-05-01    49220000   2042
# 2019-06-01    47204500   2131
# 2019-07-01    12643500   2025
# 2019-08-01    47223500   1968
# 2019-09-01    57420500   2063
# 2019-10-01    59286000   2083
# 2019-11-01    61008500   2088
# 2019-12-01    69387000   2198
# 2020-01-01    67066500   2119
# 2020-02-01    44161000   1987
# 2020-03-01    35907000   1755
# 2020-04-01    43411000   1948
# 2020-05-01    47947500   2030
# ...

# %%
df_1_logdiff = np.log(df_1).diff().dropna()
df_1_logdiff

model = VAR(df_1_logdiff)
results = model.fit(8)
results.summary()
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 05, May, 2021
# Time:                     18:40:32
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -5.31617
# Nobs:                     27.0000    HQIC:                  -6.46274
# Log likelihood:           51.1748    FPE:                 0.00149853
# AIC:                     -6.94796    Det(Omega_mle):     0.000564270
# --------------------------------------------------------------------
# Results for equation 무보까국밥(상인점)
# ...
#                    coefficient       std. error           t-stat            prob
# ...

# %%
def return_(x,y):
    return x+y

return_(1,2)
# Out:
# 3
