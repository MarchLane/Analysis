# %%
import numpy as np
import pandas as pd
import os
import statsmodels.api as sm
from statsmodels.tsa.api import VAR

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축')
df_sales = pd.read_excel('sangin_monthly_sales.xlsx')
df_sales = df_sales.transpose()
df_sales.columns = df_sales.iloc[0]
df_sales = df_sales.iloc[1:]
df_sales.index = df_sales['날짜']
del df_sales['날짜']
in_list = [str(i)[:10] for i in df_sales.index]
df_sales.index = in_list
df_sales['무보까국밥(상인점)'] = [int(g) for g in df_sales['무보까국밥(상인점)']]
df_sales
# Out:
# Unnamed: 0  무보까국밥(상인점)
# 2018-01-01    61898000
# 2018-02-01    49484000
# 2018-03-01    52142000
# 2018-04-01    49005500
# 2018-05-01    48055500
# 2018-06-01    45686000
# 2018-07-01    47015000
# 2018-08-01    56392000
# 2018-09-01    52158500
# 2018-10-01    49573500
# 2018-11-01    53709000
# 2018-12-01    61566000
# 2019-01-01    57038500
# 2019-02-01    54490500
# 2019-03-01    49664000
# 2019-04-01    43742000
# 2019-05-01    49220000
# 2019-06-01    47204500
# 2019-07-01    12643500
# 2019-08-01    47223500
# 2019-09-01    57420500
# 2019-10-01    59286000
# 2019-11-01    61008500
# 2019-12-01    69387000
# 2020-01-01    67066500
# 2020-02-01    44161000
# 2020-03-01    35907000
# 2020-04-01    43411000
# 2020-05-01    47947500
# 2020-06-01    42362500
# 2020-07-01    46436000
# 2020-08-01    50191500
# 2020-09-01    50576500
# 2020-10-01    60584500
# 2020-11-01    51665500
# 2020-12-01    42923500

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
df_CPI = pd.read_csv('소비자물가지수_20111~202103_월단위.csv', encoding = 'cp949')
df_CPI = df_CPI.transpose()
df_CPI.columns = df_CPI.iloc[0]
df_CPI = df_CPI.iloc[1:]
df_CPI.index = df_CPI['날짜']
del df_CPI['날짜']
df_CPI['소비자물가지수'] = [int(a.strip()) for a in df_CPI['소비자물가지수']]
df_CPI
# Out:
# 0           소비자물가지수
# 날짜
# 2011-01-01       93
# 2011-02-01       94
# 2011-03-01       94
# 2011-04-01       94
# 2011-05-01       94
# ...             ...
# 2020-11-01      106
# 2020-12-01      106
# 2021-01-01      106
# 2021-02-01      107
# 2021-03-01      107
#
# [123 rows x 1 columns]

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
df_PI = pd.read_csv('숙박_음식점_생산지수_2011~202102_월단위.csv')
df_PI = df_PI.transpose()
df_PI = df_PI.iloc[1:]
df_PI.index = df_PI[0]
del df_PI[0]
df_PI.columns = ['숙박_음식점_생산지수']
df_PI['숙박_음식점_생산지수'] = [int(b) for b in df_PI['숙박_음식점_생산지수']]
df_PI
# Out:
#             숙박_음식점_생산지수
# 0
# 2011-01-01          102
# 2011-02-01           93
# 2011-03-01           98
# 2011-04-01          101
# 2011-05-01          109
# ...                 ...
# 2020-10-01           83
# 2020-11-01           81
# 2020-12-01           66
# 2021-01-01           60
# 2021-02-01           65
#
# [122 rows x 1 columns]

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
EPU = pd.read_excel('Korea_Policy_Uncertainty_Data_월단위.xlsx')
EPU.index = EPU['Date']
del EPU['Date']
EPU_in_list = [str(EPU_in)[:10] for EPU_in in EPU.index]
EPU.index = EPU_in_list
EPU
# Out:
#             New South Korean EPU Index
# 1/1990                      129.638657
# 2/1990                       73.562210
# 3/1990                      102.012573
# 4/1990                      118.501373
# 5/1990                       45.044033
# ...                                ...
# 2020-09-01                  136.296806
# 2020-10-01                  189.379096
# 2020-11-01                  287.691066
# 2020-12-01                  182.512180
# 1/2021                      212.168949
#
# [373 rows x 1 columns]

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
df_PPI = pd.read_csv('생산자물가지수_2011~202103_월단위.csv', encoding = 'cp949')
df_PPI = df_PPI.transpose()
df_PPI.columns = df_PPI.iloc[0]
df_PPI = df_PPI.iloc[1:]
df_PPI.index = df_PPI['연월']
del df_PPI['연월']
df_PPI['생산자물가지수'] = [int(c) for c in df_PPI['생산자물가지수']]
df_PPI
# Out:
# Unnamed: 0  생산자물가지수
# 연월
# 2011-01-01      103
# 2011-02-01      104
# 2011-03-01      105
# 2011-04-01      106
# 2011-05-01      106
# ...             ...
# 2020-11-01      103
# 2020-12-01      104
# 2021-01-01      105
# 2021-02-01      106
# 2021-03-01      107
#
# [123 rows x 1 columns]

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
df_CSI = pd.read_csv('소비자동향지수_2011_202104_월단위.csv', encoding = 'cp949')
df_CSI = df_CSI.transpose()
df_CSI.columns = df_CSI.iloc[0]
df_CSI = df_CSI.iloc[1:]
df_CSI.index = df_CSI['날짜']
del df_CSI['날짜']
df_CSI['소비자동향지수'] = [int(d) for d in df_CSI['소비자동향지수']]
df_CSI
# Out:
#             소비자동향지수
# 날짜
# 2011-01-01      106
# 2011-02-01      104
# 2011-03-01      100
# 2011-04-01       99
# 2011-05-01       99
# ...             ...
# 2020-12-01       93
# 2021-01-01       96
# 2021-02-01       96
# 2021-03-01       96
# 2021-04-01       97
#
# [124 rows x 1 columns]

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
df_ESI = pd.read_csv('경제심리지수_2011~202104_월단위.csv', encoding = 'cp949')
df_ESI = df_ESI.transpose()
df_ESI.columns = df_ESI.iloc[0]
df_ESI = df_ESI.iloc[1:]
df_ESI.index = df_ESI['연월']
del df_ESI['연월']
df_ESI['경제심리지수'] = [int(e) for e in df_ESI['경제심리지수']]
df_ESI
# Out:
#             경제심리지수
# 연월
# 2011-01-01     111
# 2011-02-01     112
# 2011-03-01     109
# 2011-04-01     113
# 2011-05-01     111
# ...            ...
# 2020-12-01      86
# 2021-01-01      93
# 2021-02-01      97
# 2021-03-01     101
# 2021-04-01     105
#
# [124 rows x 1 columns]

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
df_kospi = pd.read_csv('KOSPI_2011~202104_월단위.csv', encoding = 'cp949')
df_kospi.index = df_kospi['연월']
del df_kospi['연월']
df_kospi
# Out:
#               종가
# 연월
# 2011-01-01  2070
# 2011-02-01  1939
# 2011-03-01  2107
# 2011-04-01  2192
# 2011-05-01  2142
# ...          ...
# 2020-12-01  2873
# 2021-01-01  2976
# 2021-02-01  3013
# 2021-03-01  3061
# 2021-04-01  3148
#
# [124 rows x 1 columns]

# %%
df_CPI['소비자물가지수'][0].strip()
# Out:
# '93'

# %%
df_sales
# Out:
# Unnamed: 0 무보까국밥(상인점)
# 2018-01-01   61898000
# 2018-02-01   49484000
# 2018-03-01   52142000
# 2018-04-01   49005500
# 2018-05-01   48055500
# 2018-06-01   45686000
# 2018-07-01   47015000
# 2018-08-01   56392000
# 2018-09-01   52158500
# 2018-10-01   49573500
# 2018-11-01   53709000
# 2018-12-01   61566000
# 2019-01-01   57038500
# 2019-02-01   54490500
# 2019-03-01   49664000
# 2019-04-01   43742000
# 2019-05-01   49220000
# 2019-06-01   47204500
# 2019-07-01   12643500
# 2019-08-01   47223500
# 2019-09-01   57420500
# 2019-10-01   59286000
# 2019-11-01   61008500
# 2019-12-01   69387000
# 2020-01-01   67066500
# 2020-02-01   44161000
# 2020-03-01   35907000
# 2020-04-01   43411000
# 2020-05-01   47947500
# 2020-06-01   42362500
# 2020-07-01   46436000
# 2020-08-01   50191500
# 2020-09-01   50576500
# 2020-10-01   60584500
# 2020-11-01   51665500
# 2020-12-01   42923500

# %%
df_sales['CPI'] = df_CPI['소비자물가지수']
df_sales['PI'] = df_PI['숙박_음식점_생산지수']
df_sales['EPU'] = EPU['New South Korean EPU Index']
df_sales['PPI'] = df_PPI['생산자물가지수']
df_sales['CSI'] = df_CSI['소비자동향지수']
df_sales['ESI'] = df_ESI['경제심리지수']
df_sales['kospi'] = df_kospi['종가']

df_sales.to_csv('상인점_월매출_경제변수7.csv', encoding  = 'cp949')

df_sales
# Out:
# Unnamed: 0  무보까국밥(상인점)  CPI   PI         EPU  PPI  CSI  ESI  kospi
# 2018-01-01    61898000  103   96   95.630259  103  105  100   2566
# 2018-02-01    49484000  104   89   71.157354  103  103  101   2427
# 2018-03-01    52142000  104   98  129.418991  103  103   98   2446
# 2018-04-01    49005500  104   97  103.855925  103  102  100   2515
# 2018-05-01    48055500  104  101  134.964252  103  101  102   2423
# 2018-06-01    45686000  104   98  126.329389  103  101  100   2326
# 2018-07-01    47015000  104  102  155.153873  104   99   96   2295
# 2018-08-01    56392000  105  102  149.484414  104   98   97   2323
# 2018-09-01    52158500  106   96  153.960057  105  101   99   2343
# 2018-10-01    49573500  105   98  176.211079  104   99   95   2030
# 2018-11-01    53709000  105   97  203.245371  104   97   95   2097
# 2018-12-01    61566000  104  109  243.033558  103   99   95   2041
# 2019-01-01    57038500  104   97  249.436502  103   98   92   2205
# ...

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')
df_sales = pd.read_csv('상인점_월매출_경제변수7.csv', encoding = 'cp949')
df_sales.index = df_sales['Unnamed: 0']
del df_sales['Unnamed: 0']
df_sales
# Out:
#             무보까국밥(상인점)  CPI   PI         EPU  PPI  CSI  ESI  kospi
# Unnamed: 0
# 2018-01-01    61898000  103   96   95.630259  103  105  100   2566
# 2018-02-01    49484000  104   89   71.157354  103  103  101   2427
# 2018-03-01    52142000  104   98  129.418991  103  103   98   2446
# 2018-04-01    49005500  104   97  103.855925  103  102  100   2515
# 2018-05-01    48055500  104  101  134.964252  103  101  102   2423
# 2018-06-01    45686000  104   98  126.329389  103  101  100   2326
# 2018-07-01    47015000  104  102  155.153873  104   99   96   2295
# 2018-08-01    56392000  105  102  149.484414  104   98   97   2323
# 2018-09-01    52158500  106   96  153.960057  105  101   99   2343
# 2018-10-01    49573500  105   98  176.211079  104   99   95   2030
# 2018-11-01    53709000  105   97  203.245371  104   97   95   2097
# 2018-12-01    61566000  104  109  243.033558  103   99   95   2041
# 2019-01-01    57038500  104   97  249.436502  103   98   92   2205
# ...

# %%
df_sales_log_diff = np.log(df_sales).diff().dropna()
df_sales_log_diff
# Out:
#             무보까국밥(상인점)       CPI        PI       EPU       PPI       CSI  \
# Unnamed: 0
# 2018-02-01   -0.223838  0.009662 -0.075712 -0.295596  0.000000 -0.019231
# 2018-03-01    0.052321  0.000000  0.096331  0.598161  0.000000  0.000000
# 2018-04-01   -0.062038  0.000000 -0.010257 -0.220051  0.000000 -0.009756
# 2018-05-01   -0.019576  0.000000  0.040410  0.262005  0.000000 -0.009852
# 2018-06-01   -0.050565  0.000000 -0.030153 -0.066117  0.000000  0.000000
# 2018-07-01    0.028675  0.000000  0.040005  0.205525  0.009662 -0.020001
# 2018-08-01    0.181861  0.009569  0.000000 -0.037225  0.000000 -0.010152
# 2018-09-01   -0.078040  0.009479 -0.060625  0.029501  0.009569  0.030153
# 2018-10-01   -0.050831 -0.009479  0.020619  0.134989 -0.009569 -0.020001
# 2018-11-01    0.080124  0.000000 -0.010257  0.142731  0.000000 -0.020409
# 2018-12-01    0.136529 -0.009569  0.116637  0.178786 -0.009662  0.020409
# 2019-01-01   -0.076383  0.000000 -0.116637  0.026005  0.000000 -0.010152
# ...

# %%
var = pd.DataFrame()
var['sales'] = df_sales_log_diff['무보까국밥(상인점)']
var['CPI'] = df_sales_log_diff['CPI']
var
# Out:
#                sales       CPI
# Unnamed: 0
# 2018-02-01 -0.223838  0.009662
# 2018-03-01  0.052321  0.000000
# 2018-04-01 -0.062038  0.000000
# 2018-05-01 -0.019576  0.000000
# 2018-06-01 -0.050565  0.000000
# 2018-07-01  0.028675  0.000000
# 2018-08-01  0.181861  0.009569
# 2018-09-01 -0.078040  0.009479
# 2018-10-01 -0.050831 -0.009479
# 2018-11-01  0.080124  0.000000
# 2018-12-01  0.136529 -0.009569
# 2019-01-01 -0.076383  0.000000
# 2019-02-01 -0.045700  0.009569
# 2019-03-01 -0.092746 -0.009569
# 2019-04-01 -0.126972  0.009569
# 2019-05-01  0.117991  0.000000
# 2019-06-01 -0.041811  0.000000
# 2019-07-01 -1.317346  0.000000
# 2019-08-01  1.317748  0.000000
# 2019-09-01  0.195510  0.000000
# 2019-10-01  0.031972  0.000000
# 2019-11-01  0.028640  0.000000
# 2019-12-01  0.128686  0.000000
# 2020-01-01 -0.034015  0.009479
# 2020-02-01 -0.417843  0.000000
# 2020-03-01 -0.206910  0.000000
# 2020-04-01  0.189781 -0.009479
# 2020-05-01  0.099394  0.000000
# ...

# %%
model = VAR(var)
results_all = model.fit(maxlags = 10, ic = 'aic')
results_all.summary()
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 08, Aug, 2021
# Time:                     21:24:24
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -13.3941
# Nobs:                     25.0000    HQIC:                  -14.8739
# Log likelihood:           164.076    FPE:                9.03349e-07
# AIC:                     -15.4419    Det(Omega_mle):     2.66821e-07
# --------------------------------------------------------------------
# Results for equation sales
# ...
#                coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------
# ...
