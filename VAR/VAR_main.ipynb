# %%
import numpy as np
import pandas as pd
import os
import statsmodels.api as sm
from statsmodels.tsa.api import VAR

# %%
os.chdir(r'C:\Users\alswo\Desktop\논문\데이터\EPU')
EPU_KO = pd.read_excel('Korea_Policy_Uncertainty_Data.xlsx')
EPU_KO
# Out:
#                                                   Date  \
# 0                                  1990-01-01 00:00:00
# 1                                  1990-02-01 00:00:00
# 2                                  1990-03-01 00:00:00
# 3                                  1990-04-01 00:00:00
# 4                                  1990-05-01 00:00:00
# ..                                                 ...
# 364                                2020-05-01 00:00:00
# 365                                2020-06-01 00:00:00
# 366                                2020-07-01 00:00:00
# 367                                2020-08-01 00:00:00
# 368  Source: “Measuring Economic Policy Uncertainty...
#
#      New South Korean EPU Index
# 0                    129.638657
# 1                     73.562210
# 2                    102.012573
# 3                    118.501373
# 4                     45.044033
# ..                          ...
# 364                  252.086815
# 365                  245.735738
# ...

# %%
os.chdir(r'C:\Users\alswo\Desktop\논문\데이터\EPU')
EPU_US = pd.read_excel('US_Policy_Uncertainty_Data.xlsx')

ten = 0
ele = 0
twe = 0
thi = 0
fou = 0
fif = 0
six = 0
sev = 0
eig = 0
nin = 0

for n in range(0, len(EPU_US)) :
    if str(EPU_US['Year'][n]) == '2010' :
        ten += EPU_US['News_Based_Policy_Uncert_Index'][n]        
    elif str(EPU_US['Year'][n]) == '2011' :
        ele += EPU_US['News_Based_Policy_Uncert_Index'][n]
    elif str(EPU_US['Year'][n]) == '2012' :
        twe += EPU_US['News_Based_Policy_Uncert_Index'][n]
    elif str(EPU_US['Year'][n]) == '2013' :
        thi += EPU_US['News_Based_Policy_Uncert_Index'][n]
    elif str(EPU_US['Year'][n]) == '2014' :
        fou += EPU_US['News_Based_Policy_Uncert_Index'][n]
    elif str(EPU_US['Year'][n]) == '2015' :
        fif += EPU_US['News_Based_Policy_Uncert_Index'][n]
    elif str(EPU_US['Year'][n]) == '2016' :
        six += EPU_US['News_Based_Policy_Uncert_Index'][n]
    elif str(EPU_US['Year'][n]) == '2017' :
        sev += EPU_US['News_Based_Policy_Uncert_Index'][n]
    elif str(EPU_US['Year'][n]) == '2018' :
        eig += EPU_US['News_Based_Policy_Uncert_Index'][n]
    elif str(EPU_US['Year'][n]) == '2019' :
        nin += EPU_US['News_Based_Policy_Uncert_Index'][n]
        
y_list = [ten, ele, twe, thi, fou, fif, six, sev, eig, nin]
EPU_avg_US = []
for y in y_list :
    avg = y/12
    EPU_avg_US.append(avg)

# %%
EPU_avg_US
# Out:
# [147.64562924702963,
#  157.35208066304526,
#  157.97692489624023,
#  137.96054712931314,
#  92.46715672810872,
#  112.9413948059082,
#  145.12823994954428,
#  142.39565467834473,
#  153.193239847819,
#  188.69571367899576]

# %%
ten = 0
ele = 0
twe = 0
thi = 0
fou = 0
fif = 0
six = 0
sev = 0
eig = 0
nin = 0

for n in range(0, len(EPU_KO)) :
    if str(EPU_KO['Date'][n])[:4] == '2010' :
        ten += EPU_KO['New South Korean EPU Index'][n]        
    elif str(EPU_KO['Date'][n])[:4] == '2011' :
        ele += EPU_KO['New South Korean EPU Index'][n]
    elif str(EPU_KO['Date'][n])[:4] == '2012' :
        twe += EPU_KO['New South Korean EPU Index'][n]
    elif str(EPU_KO['Date'][n])[:4] == '2013' :
        thi += EPU_KO['New South Korean EPU Index'][n]
    elif str(EPU_KO['Date'][n])[:4] == '2014' :
        fou += EPU_KO['New South Korean EPU Index'][n]
    elif str(EPU_KO['Date'][n])[:4] == '2015' :
        fif += EPU_KO['New South Korean EPU Index'][n]
    elif str(EPU_KO['Date'][n])[:4] == '2016' :
        six += EPU_KO['New South Korean EPU Index'][n]
    elif str(EPU_KO['Date'][n])[:4] == '2017' :
        sev += EPU_KO['New South Korean EPU Index'][n]
    elif str(EPU_KO['Date'][n])[:4] == '2018' :
        eig += EPU_KO['New South Korean EPU Index'][n]
    elif str(EPU_KO['Date'][n])[:4] == '2019' :
        nin += EPU_KO['New South Korean EPU Index'][n]

# %%
y_list = [ten, ele, twe, thi, fou, fif, six, sev, eig, nin]
EPU_avg = []
for y in y_list :
    avg = y/12
    EPU_avg.append(avg)

# %%
EPU_avg
# Out:
# [148.72453816731772,
#  167.0255947113037,
#  163.27497227986655,
#  130.60922368367514,
#  81.88151391347249,
#  128.246919631958,
#  188.80948996970474,
#  160.7715071242143,
#  145.20371016773845,
#  257.3615063754893]

# %%
os.chdir(r'C:\Users\alswo\Desktop\논문\데이터\세계품목별국가별수출')
KOR_US_ex = pd.read_csv('KOR_US_87546073.csv')
KOR_US_ex = KOR_US_ex.drop(['Classification', 'Period', 'Period Desc.', 'Period Desc.', 'Is Leaf Code', 
          'Reporter Code', 'Alt Qty Unit Code', 'Alt Qty Unit', 'Alt Qty', 'Netweight (kg)', 
          'Gross weight (kg)', 'CIF Trade Value (US$)', 'FOB Trade Value (US$)', 'Flag', 
          'Aggregate Level', '2nd Partner Code', 'Customs Proc. Code', 'Customs',
           'Mode of Transport Code', 'Mode of Transport', 'Qty Unit', 'Qty Unit Code', 
          'Qty', '2nd Partner', '2nd Partner ISO', 'Commodity',
                 'Trade Flow Code'], axis = 1)
KOR_US_ex = KOR_US_ex.sort_values(by = ['Year', 'Commodity Code'])
KOR_US_ex = KOR_US_ex.reset_index(drop = True)
KOR_US_ex
# Out:
#     Year Trade Flow       Reporter Reporter ISO  Partner Code Partner  \
# 0   2010     Export  Rep. of Korea          KOR           842     USA
# 1   2010     Export  Rep. of Korea          KOR           842     USA
# 2   2010     Export  Rep. of Korea          KOR           842     USA
# 3   2010     Export  Rep. of Korea          KOR           842     USA
# 4   2011     Export  Rep. of Korea          KOR           842     USA
# 5   2011     Export  Rep. of Korea          KOR           842     USA
# 6   2011     Export  Rep. of Korea          KOR           842     USA
# 7   2011     Export  Rep. of Korea          KOR           842     USA
# 8   2012     Export  Rep. of Korea          KOR           842     USA
# 9   2012     Export  Rep. of Korea          KOR           842     USA
# 10  2012     Export  Rep. of Korea          KOR           842     USA
# 11  2012     Export  Rep. of Korea          KOR           842     USA
# ...

# %%
os.chdir(r'C:\Users\alswo\Desktop\논문\데이터\세계품목별국가별수출')
KOR_US_ex_2 = pd.read_csv('KOR_US_87546073_2.csv')
KOR_US_ex_2 = KOR_US_ex_2.drop(['Classification', 'Period', 'Period Desc.', 'Period Desc.', 'Is Leaf Code', 
          'Reporter Code', 'Alt Qty Unit Code', 'Alt Qty Unit', 'Alt Qty', 'Netweight (kg)', 
          'Gross weight (kg)', 'CIF Trade Value (US$)', 'FOB Trade Value (US$)', 'Flag', 
          'Aggregate Level', '2nd Partner Code', 'Customs Proc. Code', 'Customs',
           'Mode of Transport Code', 'Mode of Transport', 'Qty Unit', 'Qty Unit Code', 
          'Qty', '2nd Partner', '2nd Partner ISO', 'Commodity',
                 'Trade Flow Code'], axis = 1)
KOR_US_ex_2 = KOR_US_ex_2.sort_values(by = ['Year', 'Commodity Code'])
KOR_US_ex_2 = KOR_US_ex_2.reset_index(drop = True)
KOR_US_ex_2
# Out:
#     Year Trade Flow       Reporter Reporter ISO  Partner Code Partner  \
# 0   2015     Export  Rep. of Korea          KOR           842     USA
# 1   2015     Export  Rep. of Korea          KOR           842     USA
# 2   2015     Export  Rep. of Korea          KOR           842     USA
# 3   2015     Export  Rep. of Korea          KOR           842     USA
# 4   2016     Export  Rep. of Korea          KOR           842     USA
# 5   2016     Export  Rep. of Korea          KOR           842     USA
# 6   2016     Export  Rep. of Korea          KOR           842     USA
# 7   2016     Export  Rep. of Korea          KOR           842     USA
# 8   2017     Export  Rep. of Korea          KOR           842     USA
# 9   2017     Export  Rep. of Korea          KOR           842     USA
# 10  2017     Export  Rep. of Korea          KOR           842     USA
# 11  2017     Export  Rep. of Korea          KOR           842     USA
# ...

# %%
KOR_US_ex = pd.concat([KOR_US_ex, KOR_US_ex_2])
KOR_US_ex
# Out:
#     Year Trade Flow       Reporter Reporter ISO  Partner Code Partner  \
# 0   2010     Export  Rep. of Korea          KOR           842     USA
# 1   2010     Export  Rep. of Korea          KOR           842     USA
# 2   2010     Export  Rep. of Korea          KOR           842     USA
# 3   2010     Export  Rep. of Korea          KOR           842     USA
# 4   2011     Export  Rep. of Korea          KOR           842     USA
# 5   2011     Export  Rep. of Korea          KOR           842     USA
# 6   2011     Export  Rep. of Korea          KOR           842     USA
# 7   2011     Export  Rep. of Korea          KOR           842     USA
# 8   2012     Export  Rep. of Korea          KOR           842     USA
# 9   2012     Export  Rep. of Korea          KOR           842     USA
# 10  2012     Export  Rep. of Korea          KOR           842     USA
# 11  2012     Export  Rep. of Korea          KOR           842     USA
# ...

# %%
hs54 = []
hs60 = []
hs73 = []
hs87 = []

for i in range(0, len(KOR_US_ex)) :
    if KOR_US_ex.iloc[i][7] == 54 :
        hs54.append(KOR_US_ex.iloc[i][8])
    elif KOR_US_ex.iloc[i][7] == 60 :
        hs60.append(KOR_US_ex.iloc[i][8])
    elif KOR_US_ex.iloc[i][7] == 73 :
        hs73.append(KOR_US_ex.iloc[i][8])
    elif KOR_US_ex.iloc[i][7] == 87 :
        hs87.append(KOR_US_ex.iloc[i][8])

# %%
EPU_avg
# Out:
# [148.72453816731772,
#  167.0255947113037,
#  163.27497227986655,
#  130.60922368367514,
#  81.88151391347249,
#  128.246919631958,
#  188.80948996970474,
#  160.7715071242143,
#  145.20371016773845,
#  257.3615063754893]

# %%
year_list = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']

# %%
EPU_avg_US
# Out:
# [147.64562924702963,
#  157.35208066304526,
#  157.97692489624023,
#  137.96054712931314,
#  92.46715672810872,
#  112.9413948059082,
#  145.12823994954428,
#  142.39565467834473,
#  153.193239847819,
#  188.69571367899576]

# %%
df_1 = pd.DataFrame()
df_1['hs54'] = hs54
df_1['hs60'] = hs60
df_1['hs87'] = hs87
df_1['hs73'] = hs73
df_1['EPU_KO'] = EPU_avg
df_1['EPU_US'] = EPU_avg_US
df_1.index = year_list
df_1
# Out:
#            hs54       hs60         hs87        hs73      EPU_KO      EPU_US
# 2010  153317883  209679656  10790444938  1632730068  148.724538  147.645629
# 2011  183022413  257405227  13811347289  2284339562  167.025595  157.352081
# 2012  215116890  244224806  16358748209  2735682396  163.274972  157.976925
# 2013  216488436  241484532  18441498306  2607430734  130.609224  137.960547
# 2014  213469371  247286533  21273646981  3620275537   81.881514   92.467157
# 2015  212696766  202062452  24120735850  2139722658  128.246920  112.941395
# 2016  190850465  193523759  22100627858  1818184903  188.809490  145.128240
# 2017  186272027  173022837  20005052608  2645554445  160.771507  142.395655
# 2018  231628979  181479984  19463370186  2030446263  145.203710  153.193240
# 2019  227926988  181749403  21819037656  1939825837  257.361506  188.695714

# %%
df_1_pro = np.log(df_1).diff().dropna()
df_1_pro  ##분산차분
# Out:
#           hs54      hs60      hs87      hs73    EPU_KO    EPU_US
# 2011  0.177095  0.205071  0.246830  0.335823  0.116051  0.063671
# 2012  0.161573 -0.052562  0.169272  0.180304 -0.022711  0.003963
# 2013  0.006356 -0.011284  0.119841 -0.048016 -0.223226 -0.135481
# 2014 -0.014044  0.023742  0.142866  0.328185 -0.466937 -0.400114
# 2015 -0.003626 -0.201971  0.125603 -0.525874  0.448684  0.200016
# 2016 -0.108377 -0.043177 -0.087466 -0.162838  0.386781  0.250749
# 2017 -0.024282 -0.111977 -0.099621  0.375042 -0.160754 -0.019008
# 2018  0.217929  0.047722 -0.027451 -0.264625 -0.101846  0.073091
# 2019 -0.016112  0.001483  0.114249 -0.045657  0.572344  0.208436

# %%
del df_1_pro['hs87']
del df_1_pro['hs73']
df_1_pro
# Out:
#           hs54      hs60    EPU_KO    EPU_US
# 2011  0.177095  0.205071  0.116051  0.063671
# 2012  0.161573 -0.052562 -0.022711  0.003963
# 2013  0.006356 -0.011284 -0.223226 -0.135481
# 2014 -0.014044  0.023742 -0.466937 -0.400114
# 2015 -0.003626 -0.201971  0.448684  0.200016
# 2016 -0.108377 -0.043177  0.386781  0.250749
# 2017 -0.024282 -0.111977 -0.160754 -0.019008
# 2018  0.217929  0.047722 -0.101846  0.073091
# 2019 -0.016112  0.001483  0.572344  0.208436

# %%
del df_1['hs87']
del df_1['hs73']
df_1
# Out:
#             hs54        hs60      EPU_KO     EPU_US
# 2011  29704530.0  47725571.0   18.301057   9.706451
# 2012  32094477.0 -13180421.0   -3.750622   0.624844
# 2013   1371546.0  -2740274.0  -32.665749 -20.016378
# 2014  -3019065.0   5802001.0  -48.727710 -45.493390
# 2015   -772605.0 -45224081.0   46.365406  20.474238
# 2016 -21846301.0  -8538693.0   60.562570  32.186845
# 2017  -4578438.0 -20500922.0  -28.037983  -2.732585
# 2018  45356952.0   8457147.0  -15.567797  10.797585
# 2019  -3701991.0    269419.0  112.157796  35.502474

# %%
df_1 = df_1.diff().dropna()
df_1 ## 차분
# Out:
#             hs54        hs60      EPU_KO     EPU_US
# 2012   2389947.0 -60905992.0  -22.051679  -9.081607
# 2013 -30722931.0  10440147.0  -28.915126 -20.641222
# 2014  -4390611.0   8542275.0  -16.061961 -25.477013
# 2015   2246460.0 -51026082.0   95.093115  65.967628
# 2016 -21073696.0  36685388.0   14.197165  11.712607
# 2017  17267863.0 -11962229.0  -88.600553 -34.919430
# 2018  49935390.0  28958069.0   12.470186  13.530170
# 2019 -49058943.0  -8187728.0  127.725593  24.704889

# %%
model = VAR(df_1)
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   % freq, ValueWarning)

# %%
results = model.fit(1)
results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 30, Apr, 2021
# Time:                     17:31:14
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    11.7299
# Nobs:                     7.00000    HQIC:                   9.97434
# Log likelihood:          -61.3259    FPE:                    619835.
# AIC:                      11.8845    Det(Omega_mle):         0.00000
# --------------------------------------------------------------------
# Results for equation hs54
# ...
#                coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------
# const      -8325454.465240  13973813.050333           -0.596           0.551
# L1.hs54          -0.688973         0.603811           -1.141           0.254
# ...

# %%
df_1_pro
# Out:
#           hs54      hs60    EPU_KO    EPU_US
# 2011  0.177095  0.205071  0.116051  0.063671
# 2012  0.161573 -0.052562 -0.022711  0.003963
# 2013  0.006356 -0.011284 -0.223226 -0.135481
# 2014 -0.014044  0.023742 -0.466937 -0.400114
# 2015 -0.003626 -0.201971  0.448684  0.200016
# 2016 -0.108377 -0.043177  0.386781  0.250749
# 2017 -0.024282 -0.111977 -0.160754 -0.019008
# 2018  0.217929  0.047722 -0.101846  0.073091
# 2019 -0.016112  0.001483  0.572344  0.208436

# %%
df_1_pro.to_csv('df_1_temp_pro.csv', encoding = 'cp949')

# %%
df_1.to_csv('df_1_temp.csv', encoding = 'cp949')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\alswo\\Desktop\\논문\\데이터\\세계품목별국가별수출'

# %%
os.chdir(r'C:\Users\alswo\Desktop\논문\데이터\세계품목별국가별수출')
df_ex = pd.read_csv('var_example.csv')
df_ex
# Out:
#    March  Magellan  Starry
# 0      1         5       7
# 1     11        15      17
# 2     21        25      27
# 3     31        35      37
# 4     41        45      47
# 5     51        55      57
# 6     61        65      67
# 7     71        75      77
# 8     81        85      87
# 9     91        95      97

# %%
df_ex_pro = np.log(df_ex).diff().dropna()
df_ex_pro
# Out:
#       March  Magellan    Starry
# 1  2.397895  1.098612  0.887303
# 2  0.646627  0.510826  0.462624
# 3  0.389465  0.336472  0.315081
# 4  0.279585  0.251314  0.239230
# 5  0.218254  0.200671  0.192904
# 6  0.179048  0.167054  0.161641
# 7  0.151806  0.143101  0.139113
# 8  0.131769  0.125163  0.122103
# 9  0.116410  0.111226  0.108803

# %%
df_ex_pro = df_ex.diff().dropna()
df_ex_pro
# Out:
#    March  Magellan  Starry
# 1   10.0      10.0    10.0
# 2   10.0      10.0    10.0
# 3   10.0      10.0    10.0
# 4   10.0      10.0    10.0
# 5   10.0      10.0    10.0
# 6   10.0      10.0    10.0
# 7   10.0      10.0    10.0
# 8   10.0      10.0    10.0
# 9   10.0      10.0    10.0

# %%
os.chdir(r'C:\Users\alswo\Desktop\논문\데이터\세계품목별국가별수출')
df_ex = pd.read_csv('var_example.csv')
df_ex
# Out:
#    March  Magellan  Starry
# 0      1         5       7
# 1     11        15      17
# 2     21        25      27
# 3     31        35      37
# 4     41        45      47
# 5     51        55      57
# 6     61        65      67
# 7     71        75      77
# 8     81        85      87
# 9     91        95      97

# %%
df_ex_pro = np.log(df_ex).dropna()
df_ex_pro
# Out:
#       March  Magellan    Starry
# 0  0.000000  1.609438  1.945910
# 1  2.397895  2.708050  2.833213
# 2  3.044522  3.218876  3.295837
# 3  3.433987  3.555348  3.610918
# 4  3.713572  3.806662  3.850148
# 5  3.931826  4.007333  4.043051
# 6  4.110874  4.174387  4.204693
# 7  4.262680  4.317488  4.343805
# 8  4.394449  4.442651  4.465908
# 9  4.510860  4.553877  4.574711

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축')

# %%
df_1 = pd.read_excel('상인점_이상치_제거완료_VAR전처리_210430_정민재.xlsx')
#df_1

# %%
df_1.index = df_1['날짜']
del df_1['날짜']
#df_1

# %%
df_1 = df_1.diff().dropna()
df_1 ## 차분
# Out:
#                      기온(°C)  강수량(mm)  풍속(m/s)  습도(%)       매출액
# 날짜
# 2017-11-27 01:00:00    -0.8      0.0     -0.8    4.0       0.0
# 2017-11-27 02:00:00    -0.6      0.0      0.0    1.0       0.0
# 2017-11-27 03:00:00    -0.3      0.0      0.9    2.0       0.0
# 2017-11-27 04:00:00    -0.2      0.0     -1.0    0.0       0.0
# 2017-11-27 05:00:00     0.1      0.0     -0.1   -5.0       0.0
# ...                     ...      ...      ...    ...       ...
# 2020-08-18 20:00:00    -2.0      0.0     -1.5   12.0   70500.0
# 2020-08-18 21:00:00    -0.1      0.0      0.4   -3.0 -123000.0
# 2020-08-18 22:00:00    -1.4      0.0     -0.8    8.0  -45500.0
# 2020-08-18 23:00:00    -1.3      0.0      0.3    6.0   50000.0
# 2020-08-19 00:00:00    -0.6      0.0      0.4    4.0   -5500.0
#
# [23904 rows x 5 columns]

# %%
df_1 = np.log(df_1).diff()
df_1  ##분산차분
# Out:
#                        기온(°C)  강수량(mm)   풍속(m/s)     습도(%)       매출액
# 날짜
# 2017-11-27 00:00:00       NaN      NaN       NaN       NaN       NaN
# 2017-11-27 01:00:00 -0.367725      NaN -1.098612  0.044452       NaN
# 2017-11-27 02:00:00 -0.405465      NaN  0.000000  0.010811       NaN
# 2017-11-27 03:00:00 -0.287682      NaN  1.178655  0.021277       NaN
# 2017-11-27 04:00:00 -0.251314      NaN -1.466337  0.000000       NaN
# ...                       ...      ...       ...       ...       ...
# 2020-08-18 20:00:00 -0.063513      NaN -0.916291  0.211309  0.411464
# 2020-08-18 21:00:00 -0.003284      NaN  0.336472 -0.048790 -0.887987
# 2020-08-18 22:00:00 -0.047147      NaN -0.847298  0.125163 -0.753045
# 2020-08-18 23:00:00 -0.045863      NaN  0.405465  0.084557  0.804048
# 2020-08-19 00:00:00 -0.021899      NaN  0.367725  0.052644 -0.062699
#
# [23905 rows x 5 columns]

# %%
model = VAR(df_1)
results = model.fit(10)
results.summary()
# Out:
# C:\Users\alswo\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 30, Apr, 2021
# Time:                     18:17:37
# --------------------------------------------------------------------
# No. of Equations:         5.00000    BIC:                    22.6616
# Nobs:                     23894.0    HQIC:                   22.6033
# Log likelihood:          -438973.    FPE:                6.37314e+09
# AIC:                      22.5754    Det(Omega_mle):     6.30555e+09
# --------------------------------------------------------------------
# Results for equation 기온(°C)
# ...
#                  coefficient       std. error           t-stat            prob
# ...

# %%
os.chdir(r'G:\공유 드라이브\SicParvisMagna\데이터\인공지능모델_데이터셋구축\경제지표')

# %%
KOSPI= pd.read_csv('KOSPI_2011~202104_월단위.csv', encoding = 'cp949')

# %%
df_2 = KOSPI

# %%
df_2.index = df_2['연월']
del df_2['연월']
# Out:
#               종가      대비    등락률  종가기준_최고  종가기준_최저  장중기준_최고  장중기준_최저  \
# 연월
# 2021/04  3147.86   86.44   2.82  3220.70  3087.40  3223.05  3069.68
# 2021/03  3061.42   48.47   1.61  3082.99  2958.12  3096.50  2929.36
# 2021/02  3012.95   36.74   1.23  3163.25  2994.98  3180.94  2947.24
# 2021/01  2976.21  102.74   3.58  3208.99  2944.45  3266.23  2869.11
# 2020/12  2873.47  282.13  10.89  2873.47  2634.25  2878.21  2611.67
# ...          ...     ...    ...      ...      ...      ...      ...
# 2011/05  2142.47  -49.89  -2.28  2228.96  2035.87  2229.09  2030.68
# 2011/04  2192.36   85.66   4.07  2216.00  2089.40  2231.47  2081.98
# 2011/03  2106.70  167.40   8.63  2106.70  1923.92  2106.74  1882.09
# 2011/02  1939.30 -130.43  -6.30  2081.74  1939.30  2107.83  1935.93
# 2011/01  2069.73   18.73   0.91  2115.69  2069.73  2121.06  2054.83
#
#                 거래량         거래대금          시가총액
# 연월
# 2021/04  31066512.0  346210093.0  2.196645e+09
# ...
